# %%
import pandas as pd

df = pd.read_csv('aluguel.csv', sep=';')

# %%
df
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %%
df[['Bairro', 'Valor']][:4]
# Out:
#             Bairro   Valor
# 0       Copacabana  1700.0
# 1  Jardim Botânico  7000.0
# 2  Barra da Tijuca  5200.0
# 3           Centro   800.0

# %%
df[['Bairro', 'Valor']].head()
# Out:
#             Bairro   Valor
# 0       Copacabana  1700.0
# 1  Jardim Botânico  7000.0
# 2  Barra da Tijuca  5200.0
# 3           Centro   800.0
# 4     Higienópolis   800.0

# %%
df[['Bairro', 'Valor']].tail()
# Out:
#                      Bairro   Valor
# 32955                Centro   800.0
# 32956           Jacarepaguá  1800.0
# 32957  São Francisco Xavier  1400.0
# 32958                Leblon  3000.0
# 32959                Centro  6500.0

# %%
df
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %%
df[df['Tipo'] == 'Apartamento']
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# 6      Apartamento              Cachambi        2      0       0    50
# 10     Apartamento                Centro        1      0       0    36
# ...            ...                   ...      ...    ...     ...   ...
# 32951  Apartamento        Vila Valqueire        2      0       0    52
# 32953  Apartamento                 Méier        2      0       0    70
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 3       800.0       390.0  20.0
# 4       800.0       230.0   NaN
# ...

# %%
df[df['Tipo'] != 'Apartamento']
# Out:
#                           Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                    Quitinete       Copacabana        1      0       0    40
# 1                         Casa  Jardim Botânico        2      0       1   100
# 2      Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 7           Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8           Casa de Condomínio            Ramos        2      2       0    65
# ...                        ...              ...      ...    ...     ...   ...
# 32948  Conjunto Comercial/Sala           Centro        0      0       0    32
# 32952       Casa de Condomínio  Barra da Tijuca        5      3       4   450
# 32954              Box/Garagem           Centro        0      0       0   755
# 32955                Quitinete           Centro        0      0       0    27
# 32959  Conjunto Comercial/Sala           Centro        0      0       0   250
#
# ...

# %%
df[~(df['Tipo'] == 'Apartamento')]
# Out:
#                           Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                    Quitinete       Copacabana        1      0       0    40
# 1                         Casa  Jardim Botânico        2      0       1   100
# 2      Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 7           Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8           Casa de Condomínio            Ramos        2      2       0    65
# ...                        ...              ...      ...    ...     ...   ...
# 32948  Conjunto Comercial/Sala           Centro        0      0       0    32
# 32952       Casa de Condomínio  Barra da Tijuca        5      3       4   450
# 32954              Box/Garagem           Centro        0      0       0   755
# 32955                Quitinete           Centro        0      0       0    27
# 32959  Conjunto Comercial/Sala           Centro        0      0       0   250
#
# ...

# %%
df[(df['Tipo'] == 'Apartamento') & (df['Valor'] > 7000)]
# Out:
#               Tipo      Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 15     Apartamento  Copacabana        4      3       1   243  13000.0
# 33     Apartamento  Copacabana        3      1       2   378  10000.0
# 62     Apartamento   Península        4      3       4   267  18000.0
# 71     Apartamento     Ipanema        3      2       1   150   8000.0
# 73     Apartamento     Ipanema        3      1       1   140   7900.0
# ...            ...         ...      ...    ...     ...   ...      ...
# 32902  Apartamento      Leblon        2      1       1    90  10500.0
# 32903  Apartamento      Leblon        3      2       1   200  16000.0
# 32904  Apartamento      Leblon        4      3       2   280  10000.0
# 32909  Apartamento       Lagoa        3      3       1   225  12000.0
# 32949  Apartamento     Ipanema        3      1       2   150  15000.0
#
#        Condominio   IPTU
# 15         2000.0  803.0
# 33         2150.0  700.0
# 62         3100.0  400.0
# ...

# %%
tipo_apartamento = df['Tipo'] == 'Apartamento'
preco_alto = df['Valor'] > 7000
iptu_baixo = df['IPTU'] < 400

# %%
df[~(tipo_apartamento & preco_alto & iptu_baixo)]
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %%
df.query("Tipo == 'Apartamento' and Valor > 7000")
# Out:
#               Tipo      Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 15     Apartamento  Copacabana        4      3       1   243  13000.0
# 33     Apartamento  Copacabana        3      1       2   378  10000.0
# 62     Apartamento   Península        4      3       4   267  18000.0
# 71     Apartamento     Ipanema        3      2       1   150   8000.0
# 73     Apartamento     Ipanema        3      1       1   140   7900.0
# ...            ...         ...      ...    ...     ...   ...      ...
# 32902  Apartamento      Leblon        2      1       1    90  10500.0
# 32903  Apartamento      Leblon        3      2       1   200  16000.0
# 32904  Apartamento      Leblon        4      3       2   280  10000.0
# 32909  Apartamento       Lagoa        3      3       1   225  12000.0
# 32949  Apartamento     Ipanema        3      1       2   150  15000.0
#
#        Condominio   IPTU
# 15         2000.0  803.0
# 33         2150.0  700.0
# 62         3100.0  400.0
# ...

# %%
df.sort_values(by='Valor', ascending=False).head(10)
# Out:
#                           Tipo                    Bairro  Quartos  Vagas  \
# 5592            Prédio Inteiro               Jacarepaguá        0     15
# 4595   Galpão/Depósito/Armazém                     Irajá        0      5
# 23491              Apartamento                  Botafogo        4      1
# 25632           Prédio Inteiro                   Humaitá        0     96
# 26327  Conjunto Comercial/Sala                      Caju        0      0
# 21024              Apartamento  Recreio dos Bandeirantes        3      2
# 28047           Prédio Inteiro                   Humaitá        0     96
# 25775           Prédio Inteiro                    Centro        0      0
# 8377   Conjunto Comercial/Sala                    Centro        0      1
# 17740  Galpão/Depósito/Armazém                    Centro        0     83
#
#        Suites   Area        Valor  Condominio     IPTU
# 5592        0   1200  120000000.0         NaN  10000.0
# ...

# %%
df[tipo_apartamento & preco_alto & iptu_baixo].sort_values('Condominio', ascending=False)
# Out:
#               Tipo       Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 32902  Apartamento       Leblon        2      1       1    90  10500.0
# 16409  Apartamento  São Conrado        4      3       2   460   9500.0
# 14521  Apartamento  São Conrado        3      3       1   360   8000.0
# 6710   Apartamento      Ipanema        4      4       2   400  25000.0
# 1649   Apartamento      Ipanema        4      3       1   600  42000.0
# ...            ...          ...      ...    ...     ...   ...      ...
# 19324  Apartamento       Leblon        3      1       1    90  12000.0
# 17454  Apartamento   Copacabana        3      0       2   130   8500.0
# 28321  Apartamento   Copacabana        3      0       1    98   9000.0
# 6235   Apartamento   Copacabana        3      0       1    98   9000.0
# 23751  Apartamento   Copacabana        3      0       0   160   8000.0
#
#        Condominio   IPTU
# 32902     23511.0  352.0
# 16409      9700.0    9.0
# 14521      9500.0  176.0
# ...

# %%
df[tipo_apartamento & preco_alto & iptu_baixo].sort_values(['Area', 'Condominio'], ascending=False)
# Out:
#               Tipo           Bairro  Quartos  Vagas  Suites  Area     Valor  \
# 8447   Apartamento       Copacabana        4      3       4   700   35000.0
# 1649   Apartamento          Ipanema        4      3       1   600   42000.0
# 29130  Apartamento            Lagoa        4      4       2   580   12500.0
# 24806  Apartamento  Barra da Tijuca        4      4       4   565   20000.0
# 189    Apartamento       Copacabana        3      1       1   500   15000.0
# ...            ...              ...      ...    ...     ...   ...       ...
# 17668  Apartamento           Leblon        2      1       1    80   12800.0
# 2652   Apartamento          Ipanema        2      1       2    74   10000.0
# 9169   Apartamento          Ipanema        2      2       2    70   10000.0
# 11712  Apartamento  Barra da Tijuca        1      1       0    65  600000.0
# 170    Apartamento          Ipanema        2      0       2    52   10000.0
#
#        Condominio   IPTU
# 8447       1850.0  140.0
# ...

# %%
df[df['Suites'] > 0]['Bairro'].unique()
# Out:
# array(['Jardim Botânico', 'Barra da Tijuca', 'Lins de Vasconcelos',
#        'Copacabana', 'Botafogo', 'Taquara', 'Ipanema', 'Campo Grande',
#        'Recreio dos Bandeirantes', 'Jardim Oceânico', 'Humaitá',
#        'Península', 'Jacarepaguá', 'São Conrado',
#        'Freguesia (Jacarepaguá)', 'Leblon', 'Todos os Santos', 'Lagoa',
#        'Maracanã', 'Gávea', 'Engenho de Dentro', 'Jardim Carioca',
#        'Tijuca', 'Laranjeiras', 'Arpoador', 'Catete', 'Jardim Sulacap',
#        'Oswaldo Cruz', 'Grajaú', 'Vargem Grande', 'Vila Isabel',
#        'São Francisco Xavier', 'Leme', 'Glória', 'Flamengo',
#        'Vargem Pequena', 'Tanque', 'Praça Seca', 'Pechincha', 'Centro',
#        'Andaraí', 'Itanhangá', 'Vila Valqueire', 'Urca', 'Anil', 'Joá',
#        'Curicica', 'Camorim', 'Jardim Guanabara', 'Higienópolis',
#        'Cosme Velho', 'Méier', 'São Cristóvão', 'Campinho', 'Pilares',
#        'Riachuelo', 'Vila da Penha', 'Guaratiba', 'Engenho Novo',
# ...

# %%
len(df[(df['Suites'] > 0)]['Bairro'].unique())
# Out:
# 118

# %%
df[(df['Suites'] > 0)]['Bairro'].value_counts()
# Out:
# Barra da Tijuca             3609
# Recreio dos Bandeirantes    1606
# Ipanema                     1462
# Copacabana                  1114
# Leblon                       992
#                             ...
# Bangu                          1
# Lapa                           1
# Turiaçu                        1
# Cocotá                         1
# Gardênia Azul                  1
# Name: Bairro, Length: 118, dtype: int64

# %% [markdown]
# Quais os 10 bairros com condominios mais barato do dataset?

# %%
df.sort_values('Condominio')['Bairro'].unique()[:10]
# Out:
# array(['Leblon', 'Laranjeiras', 'Andaraí', 'Copacabana', 'Vila da Penha',
#        'Tijuca', 'São Cristóvão', 'Centro', 'Recreio dos Bandeirantes',
#        'Freguesia (Jacarepaguá)'], dtype=object)

# %%
df.sort_values('Condominio')['Bairro'].unique()[:10]
# Out:
# array(['Leblon', 'Laranjeiras', 'Andaraí', 'Copacabana', 'Vila da Penha',
#        'Tijuca', 'São Cristóvão', 'Centro', 'Recreio dos Bandeirantes',
#        'Freguesia (Jacarepaguá)'], dtype=object)

# %%
pd.Series(df.sort_values('Condominio')['Bairro'].unique()).head(10)
# Out:
# 0                      Leblon
# 1                 Laranjeiras
# 2                     Andaraí
# 3                  Copacabana
# 4               Vila da Penha
# 5                      Tijuca
# 6               São Cristóvão
# 7                      Centro
# 8    Recreio dos Bandeirantes
# 9     Freguesia (Jacarepaguá)
# dtype: object

# %% [markdown]
# Calcule o IPTU por metro, crie uma coluna com esse resultado

# %%
df
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %%
df['IPTU_m'] = df['IPTU'] / df['Area']

# %%
df['IPTU_m']
# Out:
# 0        1.500000
# 1             NaN
# 2        7.406667
# 3        1.333333
# 4             NaN
#            ...
# 32955    0.925926
# 32956    0.512821
# 32957    0.770833
# 32958         NaN
# 32959    4.436000
# Name: IPTU_m, Length: 32960, dtype: float64

# %%
df
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
# ...

# %%
df.fillna(0, inplace=True)

# %%
df
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
# ...

# %% [markdown]
# Apresente os bairros com o metro mais caro de IPTU

# %%
area_maior_0 = df['Area'] > 0

# %%
df[area_maior_0].sort_values('IPTU_m', ascending=False)['Bairro'].unique()[:10]
# Out:
# array(['São Cristóvão', 'Leblon', 'Barra da Tijuca', 'Copacabana',
#        'Centro', 'Curicica', 'Ipanema', 'Jardim Botânico', 'Botafogo',
#        'Recreio dos Bandeirantes'], dtype=object)

# %%
df[df['Area'] > 0].sort_values('IPTU_m', ascending=False)['Bairro'].unique()[:10]
# Out:
# array(['São Cristóvão', 'Leblon', 'Barra da Tijuca', 'Copacabana',
#        'Centro', 'Curicica', 'Ipanema', 'Jardim Botânico', 'Botafogo',
#        'Recreio dos Bandeirantes'], dtype=object)

# %%
df.sort_values('IPTU_m', ascending=False)
# Out:
#                           Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 13887              Box/Garagem           Centro        0      0       0     0
# 28931              Box/Garagem           Centro        0      0       0     0
# 25294    Loteamento/Condomínio           Tijuca        0      0       0     0
# 12783              Box/Garagem           Centro        0      1       0     0
# 17413              Box/Garagem           Centro        0      0       0     0
# ...                        ...              ...      ...    ...     ...   ...
# 23470  Conjunto Comercial/Sala          Pilares        0      1       0    26
# 4926               Apartamento          Ipanema        2      1       1    70
# 4925               Apartamento  Barra da Tijuca        2      1       1    76
# 23473  Conjunto Comercial/Sala          Ipanema        0      1       0    30
# 11216           Prédio Inteiro           Tijuca        0      0       0   950
#
# ...

# %% [markdown]
# ###### Calcule o valor por metro, crie uma coluna com esse resultado;
# ###### Apresente os bairros com o metro mais caro de Valor~;
# ###### Apresente os mais baratos nessas condições tb;
# ###### Existem hoteis no dataset? Quais? Onde estão localizados?

# %%
df
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
# ...

# %%
df['Quartos'].value_counts()
# Out:
# 0      9851
# 2      8419
# 3      6829
# 1      4000
# 4      3065
# 5       572
# 6       137
# 7        30
# 8        19
# 10       11
# 27        7
# 9         4
# 11        4
# 12        4
# 100       2
# 14        2
# 32        1
# 22        1
# 23        1
# 24        1
# Name: Quartos, dtype: int64

# %%
df['Tipo'].unique()
# Out:
# array(['Quitinete', 'Casa', 'Conjunto Comercial/Sala', 'Apartamento',
#        'Casa de Condomínio', 'Prédio Inteiro', 'Flat', 'Loja/Salão',
#        'Galpão/Depósito/Armazém', 'Casa Comercial', 'Casa de Vila',
#        'Terreno Padrão', 'Box/Garagem', 'Loft',
#        'Loja Shopping/ Ct Comercial', 'Chácara', 'Loteamento/Condomínio',
#        'Sítio', 'Pousada/Chalé', 'Studio', 'Hotel', 'Indústria'],
#       dtype=object)

# %%
df[df["Tipo"] == "Pousada/Chalé"]
# Out:
#                Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 4721  Pousada/Chalé  Barra da Tijuca       23      0      23   862  1480.0
#
#       Condominio  IPTU  IPTU_m
# 4721       295.0   0.0     0.0

# %%
df[(df["Tipo"] == "Pousada/Chalé") | (df["Tipo"] == "Hotel")]
# Out:
#                 Tipo           Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 4721   Pousada/Chalé  Barra da Tijuca       23      0      23   862   1480.0
# 9687           Hotel       Copacabana       24      0      24  1100  38000.0
# 26977          Hotel      Laranjeiras       27      5       0   671  12000.0
#
#        Condominio    IPTU    IPTU_m
# 4721        295.0     0.0  0.000000
# 9687          0.0  7504.0  6.821818
# 26977         0.0  4900.0  7.302534

# %%
lista_tipos = ["Pousada/Chalé", "Hotel"]

# %%
lista_tipos
# Out:
# ['Pousada/Chalé', 'Hotel']

# %%
df[df['Tipo'].isin(lista_tipos)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-b95911bed980> in <module>
# ----> 1 df[df['Tipo'].isin(lista_tipos)]
#
# NameError: name 'lista_tipos' is not defined

# %%
df.sort_values('Quartos', ascending=False)
# Out:
#                           Tipo       Bairro  Quartos  Vagas  Suites  Area  \
# 657    Conjunto Comercial/Sala       Centro      100     39       0  1600
# 3661   Conjunto Comercial/Sala       Centro      100     80       0  3600
# 4347               Apartamento         Urca       32      0       1    70
# 25918           Casa Comercial  Laranjeiras       27      0      10  1000
# 30346           Casa Comercial  Laranjeiras       27      8       1  1000
# ...                        ...          ...      ...    ...     ...   ...
# 16649  Galpão/Depósito/Armazém   Bonsucesso        0      0       0  1451
# 16650               Loja/Salão     Botafogo        0     20       0  1900
# 16654  Galpão/Depósito/Armazém    Guaratiba        0      0       0   300
# 16659  Conjunto Comercial/Sala       Centro        0      0       0    85
# 32959  Conjunto Comercial/Sala       Centro        0      0       0   250
#
#           Valor  Condominio    IPTU
# 657    160000.0         NaN     NaN
# ...
